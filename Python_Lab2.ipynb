# %% [markdown]
# ### Raushan Kumar Gupta(bl.en.u4cse22086)

# %%
import pandas as pd
import numpy as np
# Load the Excel file
file_path = "LabSessionData.xlsx"
df = pd.read_excel(file_path, sheet_name="Purchase data")

# Display the dataframe
df
# Out:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs)  \
# 0      C_1           20             6                 2           386
# 1      C_2           16             3                 6           289
# 2      C_3           27             6                 2           393
# 3      C_4           19             1                 2           110
# 4      C_5           24             4                 2           280
# 5      C_6           22             1                 5           167
# 6      C_7           15             4                 2           271
# 7      C_8           18             4                 2           274
# 8      C_9           21             1                 4           148
# 9     C_10           16             2                 4           198
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# ...

# %% [markdown]
# ### Please load the data and segregate them into 2 matrices A & C (following the nomenclature of AX = C)

# %%
df=df.iloc[:, :5]
df
# dropy = df.dropna()
# dropy
# Out:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs)
# 0      C_1           20             6                 2           386
# 1      C_2           16             3                 6           289
# 2      C_3           27             6                 2           393
# 3      C_4           19             1                 2           110
# 4      C_5           24             4                 2           280
# 5      C_6           22             1                 5           167
# 6      C_7           15             4                 2           271
# 7      C_8           18             4                 2           274
# 8      C_9           21             1                 4           148
# 9     C_10           16             2                 4           198

# %%
df.columns
# Out:
# Index(['Customer', 'Candies (#)', 'Mangoes (Kg)', 'Milk Packets (#)',
#        'Payment (Rs)'],
#       dtype='object')

# %%
A=df.iloc[:,1:4]
A
# Out:
#    Candies (#)  Mangoes (Kg)  Milk Packets (#)
# 0           20             6                 2
# 1           16             3                 6
# 2           27             6                 2
# 3           19             1                 2
# 4           24             4                 2
# 5           22             1                 5
# 6           15             4                 2
# 7           18             4                 2
# 8           21             1                 4
# 9           16             2                 4

# %%
C=df.iloc[:,4:]
C
# Out:
#    Payment (Rs)
# 0           386
# 1           289
# 2           393
# 3           110
# 4           280
# 5           167
# 6           271
# 7           274
# 8           148
# 9           198

# %% [markdown]
# ### Array A and C to numpy Array

# %%
A_arr=A.to_numpy()
A_arr
C_arr=C.to_numpy()
C_arr
# Out:
# array([[386],
#        [289],
#        [393],
#        [110],
#        [280],
#        [167],
#        [271],
#        [274],
#        [148],
#        [198]], dtype=int64)

# %% [markdown]
# ### Rank of matrix A

# %%
rank_A=np.linalg.matrix_rank(A_arr)
rank_A
# Out:
# 3

# %% [markdown]
# ### inverse of matrix A

# %%
A_cost=np.linalg.pinv(A)
A_cost
# Out:
# array([[-0.01008596, -0.03124505,  0.01013951,  0.0290728 ,  0.0182907 ,
#          0.01161794, -0.00771348,  0.00095458,  0.01743623, -0.00542016],
#        [ 0.09059668,  0.07263726,  0.03172933, -0.09071908, -0.01893196,
#         -0.06926996,  0.05675464,  0.03152577, -0.07641966,  0.00357352],
#        [ 0.00299878,  0.15874243, -0.05795468, -0.06609024, -0.06295043,
#          0.03348017,  0.01541831, -0.01070461,  0.00029003,  0.05938755]])

# %% [markdown]
# ### Matrix Multiplication

# %%
cost_X=np.matmul(A_cost,C)
cost_X
# Out:
#    Payment (Rs)
# 0           1.0
# 1          55.0
# 2          18.0

# %% [markdown]
# ### Category

# %%
df['Category']=df['Payment (Rs)']>200
df['Category'].replace({True:'Rich', False:'Poor'}, inplace=True)
df
# Out:
#   Customer  Candies (#)  Mangoes (Kg)  Milk Packets (#)  Payment (Rs) Category
# 0      C_1           20             6                 2           386     Rich
# 1      C_2           16             3                 6           289     Rich
# 2      C_3           27             6                 2           393     Rich
# 3      C_4           19             1                 2           110     Poor
# 4      C_5           24             4                 2           280     Rich
# 5      C_6           22             1                 5           167     Poor
# 6      C_7           15             4                 2           271     Rich
# 7      C_8           18             4                 2           274     Rich
# 8      C_9           21             1                 4           148     Poor
# 9     C_10           16             2                 4           198     Poor

# %%
!
